# %% [markdown]
# https://www.pg4e.com/tools/sql/?PHPSESSID=70e11b4a7d0a341fe15ca7942716d152
# Initial Database Setup
# You will need access to a database to use for this course. This tool creates your database and gives you an account and password to use to connect to the database.
#
# Host:     pg.pg4e.com
# Port:     5432
# Database: pg4e_2bc91f246a
# User:     pg4e_2bc91f246a
# Password: pg4e_p_9c12bf1d4a2cd3b
# Password:  (hide/show copy)
#
#
# psql -h pg.pg4e.com -p 5432 -U pg4e_2bc91f246a pg4e_2bc91f246a
# Current database size 7829 kB
#
#
# Your database may be deleted if it gets too large or it has not been used for while. If your database is deleted, you can come back to this tool to re-create your database.
#
# You will see a pg4e_meta table in your database that is used internally by the autograder to pass information from one assignment to another assignment. The autograder will store mysterious stuff in this table and look at it later. Leave this table alone. If this table does not exist or you change the data the autograder puts in this table, the autograder may refuse to grade your assignments, or your database may be deleted as part of a maintenance process.
#
# Technical Detail on Your Database
# This database is on a shared instance of PostgreSQL. You have enough access to your database to do the homework for this class, but will not have access to some of the server-wide database wide tables that contain data about the other users on the server. This can cause PostgreSQL clients to complain with errors like the following when they try to access these server-wide databases and schemas:
#
# ERROR: permission denied for view pg_roles
# ERROR: permission denied for pg_database
# In a real production environment, you (or someone) will have a access to the all-powerful postgres account and most accounts have at least read-access to these cross-database tables.
#
# References:
#
# PostgreSQL Shared Database Hosting

# %% [markdown]
# https://www.coursera.org/learn/database-design-postgresql/lecture/llPUo/using-pythonanywhere-to-run-sql
#
# https://www.pythonanywhere.com/user/daird0311/
#
# ![Screenshot 2026-04-11 at 1.23.09 PM.png](attachment:ab0d65e1-ed66-43b3-956c-3d9cee249ce5.png)
#
# console
# now use this:
#
# 17:23 ~ $ pwd
# /home/daird0311
# 17:24 ~ $ ls
# README.txt
# 17:24 ~ $ psql -h pg.pg4e.com -p 5432 -U pg4e_2bc91f246a pg4e_2bc91f246a
# Password for user pg4e_2bc91f246a:
#
# Password: pg4e_p_9c12bf1d4a2cd3b
#
# #ok it's a little clunky you have to just paste it don't type it (ctrl v or command v) no right click paste doesn't work. You won't see that it did anything until you hit enter
#
# ![Screenshot 2026-04-11 at 1.32.06 PM.png](attachment:2f8bbac1-f6bb-4927-b0d2-9f72a899cca3.png)
# https://www.pythonanywhere.com/user/daird0311/files/home/daird0311/lesson1.sql?edit
#
# #we're working w/ lesson1.sql
# so you may want a few terminals open
# you can get into the bash and get
# 17:32 ~ $ v1 lesson1.sql
# bash: v1: command not found
# 17:33 ~ $ vi lesson1.sql
# 17:33 ~ $
#
# back to the other console
# pg4e_2bc91f246a=> dt
# pg4e_2bc91f246a-> \dt
#               List of relations
#  Schema |   Name    | Type  |      Owner
# --------+-----------+-------+-----------------
#  public | pg4e_meta | table | pg4e_2bc91f246a
# (1 row)
# pg4e_2bc91f246a->
#
# #ok you need to type into text editor FIRST
# bash: syntax error near unexpected token `('
# 17:37 ~ $ cat lesson1.sql
# SELECT COUNT(*) FROM pg4e_debug;17:37 ~ $ cat lesson1.sql
# SELECT COUNT(*) FROM pg4e_debug;
# 17:38 ~ $
#
# ![Screenshot 2026-04-11 at 1.38.54 PM.png](attachment:b0a152ce-3b79-41e2-b571-6a41d9c20f05.png)

# %% [markdown]
# Test to see if this is working
